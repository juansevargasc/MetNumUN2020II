# %% [markdown]
# ## Laboratory 7
# ## Taylor Series in Python

# %%
import math

# %% [markdown]
# **1º Exercise - Taylor series**
# * approximation of e2 with x= 2

# %%
x = 2

e_to_2 = x**0/math.factorial(0) + x**1/math.factorial(1) + x**2/math.factorial(2) + x**3/math.factorial(3) + x**4/math.factorial(4)
print(e_to_2)
# Out:
# 7.0

# %% [markdown]
# **Comparison with math library**

# %%
print(math.exp(2))
# Out:
# 7.38905609893065

# %% [markdown]
# **Loop method**
# * 5 iterations

# %%
x = 2

e_to_2 = 0
for i in range(5):
    e_to_2 += x**i/math.factorial(i)
    
print(e_to_2)
# Out:
# 7.0

# %% [markdown]
# **Loop method**
# * 10 iterations

# %%
x = 2

e_to_2 = 0
for i in range(10):
    e_to_2 += x**i/math.factorial(i)
    
print(e_to_2)
# Out:
# 7.3887125220458545

# %% [markdown]
# **Function**
# * e ^ 2

# %%
def func_e_to_2(n):
    x = 2
    e_to_2 = 0
    
    for i in range(n):
        e_to_2 += x**i/math.factorial(i)
    
    return e_to_2

# %%
out = func_e_to_2(10)
print("e ^ 2: ", out)
# Out:
# e ^ 2:  7.3887125220458545

# %% [markdown]
# **Function - More general**
# * e ^ x

# %%
def func_e(x, n):
    e_approx = 0
    for i in range(n):
        e_approx += x**i/math.factorial(i)
    
    return e_approx

# %%
out = func_e(2,10)
print(out)
# Out:
# 7.3887125220458545

# %% [markdown]
# **Comparison**
# * e ^ 5

# %%
out = func_e(5,10)
print('e ^ 5 - Taylor: ', out)

out = math.exp(5)
print('e ^ 5 - Library:', out)
# Out:
# e ^ 5 - Taylor:  143.68945656966488
# e ^ 5 - Library: 148.4131591025766

# %% [markdown]
# **Error calculations**

# %%
x = 5
for i in range(1,11):
    e_approx = func_e(x,i)
    e_exp = math.exp(x)
    e_error = abs(e_approx - e_exp)
    print(f'{i} terms: Taylor Series approx= {e_approx}, exp calc= {e_exp}, error = {e_error}')
# Out:
# 1 terms: Taylor Series approx= 1.0, exp calc= 148.4131591025766, error = 147.4131591025766
# 2 terms: Taylor Series approx= 6.0, exp calc= 148.4131591025766, error = 142.4131591025766
# 3 terms: Taylor Series approx= 18.5, exp calc= 148.4131591025766, error = 129.9131591025766
# 4 terms: Taylor Series approx= 39.33333333333333, exp calc= 148.4131591025766, error = 109.07982576924327
# 5 terms: Taylor Series approx= 65.375, exp calc= 148.4131591025766, error = 83.0381591025766
# 6 terms: Taylor Series approx= 91.41666666666667, exp calc= 148.4131591025766, error = 56.99649243590993
# 7 terms: Taylor Series approx= 113.11805555555556, exp calc= 148.4131591025766, error = 35.29510354702104
# 8 terms: Taylor Series approx= 128.61904761904762, exp calc= 148.4131591025766, error = 19.79411148352898
# 9 terms: Taylor Series approx= 138.30716765873015, exp calc= 148.4131591025766, error = 10.105991443846449
# ...

# %% [markdown]
# **Exit a loop in a determined error range**

# %%
x = 5
for i in range(1,20):
    e_approx = func_e(x,i)
    e_exp = math.exp(x)
    e_error = abs(e_approx - e_exp)
    if e_error < 1:
        break
        
print(f'{i} terms: Taylor Series approx= {e_approx}, exp calc= {e_exp}, error = {e_error}')
# Out:
# 12 terms: Taylor Series approx= 147.60384850489015, exp calc= 148.4131591025766, error = 0.8093105976864479

# %% [markdown]
# **Cosine aproximation**

# %%
def func_cos(x, n):
    cos_approx = 0
    for i in range(n):
        coef = (-1)**i
        num = x**(2*i)
        denom = math.factorial(2*i)
        cos_approx += ( coef ) * ( (num)/(denom) )
    
    return cos_approx

# %%
angle_rad = (math.radians(45))
out = func_cos(angle_rad,5)
print(out)
# Out:
# 0.7071068056832942

# %%
out = math.cos(angle_rad)
print(out)
# Out:
# 0.7071067811865476

# %%
import numpy as np
import matplotlib.pyplot as plt

# if using a Jupyter notebook, include:
# %matplotlib inline

angles = np.arange(-2*np.pi,2*np.pi,0.1)
p_cos = np.cos(angles)
t_cos = [func_cos(angle,3) for angle in angles]

fig, ax = plt.subplots()
ax.plot(angles,p_cos)
ax.plot(angles,t_cos)
ax.set_ylim([-5,5])
ax.legend(['cos() function','Taylor Series - 3 terms'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-deae1d8cdb8d> in <module>
#       7 angles = np.arange(-2*np.pi,2*np.pi,0.1)
#       8 p_cos = np.cos(angles)
# ----> 9 t_cos = [func_cos(angle,3) for angle in angles]
#      10
#      11 fig, ax = plt.subplots()
#
# <ipython-input-13-deae1d8cdb8d> in <listcomp>(.0)
#       7 angles = np.arange(-2*np.pi,2*np.pi,0.1)
#       8 p_cos = np.cos(angles)
# ----> 9 t_cos = [func_cos(angle,3) for angle in angles]
#      10
#      11 fig, ax = plt.subplots()
#
# NameError: name 'func_cos' is not defined

# %%
angles = np.arange(-2*np.pi,2*np.pi,0.1)
p_cos = np.cos(angles)

fig, ax = plt.subplots()
ax.plot(angles,p_cos)

# add lines for between 1 and 6 terms in the Taylor Series
for i in range(1,6):
    t_cos = [func_cos(angle,i) for angle in angles]
    ax.plot(angles,t_cos)

ax.set_ylim([-7,4])

# set up legend
legend_lst = ['cos() function']
for i in range(1,6):
    legend_lst.append(f'Taylor Series - {i} terms')
ax.legend(legend_lst, loc=3)

plt.show()

# %% [markdown]
# ## Functions
# * **e ^ x**
# * **sin(x)**
# * **cos(x)**
# * **1 / (1 - x)**
# * **ln(1 + x)**
# * **ln(x)**

# %% [markdown]
# * **e ^x**

# %% [markdown]
# ![Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.05.48%20a.%C2%A0m..png](attachment:Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.05.48%20a.%C2%A0m..png)

# %%
x = 5; n = 20
out = func_e(x, n)
print('e ^ 5 - Taylor: ', out)

out = math.exp(x)
print('e ^ 5 - Library:', out)
# Out:
# e ^ 5 - Taylor:  148.4131078683383
# e ^ 5 - Library: 148.4131591025766

# %%
x = 0.1
for i in range(1,11):
    e_approx = func_e(x,i)
    e_exp = math.exp(x)
    e_error = abs(e_approx - e_exp)
    print(f'{i} terms: Taylor Series approx= {e_approx}, exp calc= {e_exp}, error = {e_error}')
# Out:
# 1 terms: Taylor Series approx= 1.0, exp calc= 1.1051709180756477, error = 0.10517091807564771
# 2 terms: Taylor Series approx= 1.1, exp calc= 1.1051709180756477, error = 0.005170918075647624
# 3 terms: Taylor Series approx= 1.105, exp calc= 1.1051709180756477, error = 0.0001709180756477302
# 4 terms: Taylor Series approx= 1.1051666666666666, exp calc= 1.1051709180756477, error = 4.2514089810818945e-06
# 5 terms: Taylor Series approx= 1.1051708333333332, exp calc= 1.1051709180756477, error = 8.474231449895342e-08
# 6 terms: Taylor Series approx= 1.1051709166666666, exp calc= 1.1051709180756477, error = 1.4089811539719221e-09
# 7 terms: Taylor Series approx= 1.1051709180555553, exp calc= 1.1051709180756477, error = 2.0092372210456233e-11
# 8 terms: Taylor Series approx= 1.1051709180753966, exp calc= 1.1051709180756477, error = 2.511324481702104e-13
# 9 terms: Taylor Series approx= 1.1051709180756446, exp calc= 1.1051709180756477, error = 3.1086244689504383e-15
# ...

# %%
#Plot e ^ x
# %matplotlib inline

x_values = np.arange(-5, 10, 1)
lib_ex = np.exp(x_values)
ex = [func_e(x, 10) for x in x_values]

fig, ax = plt.subplots()
ax.plot(x_values, lib_ex)
ax.plot(x_values, ex)
ax.set_ylim([-1,10])
ax.legend(['e ^ x() function','Taylor Aprox.'])

plt.show()

# %% [markdown]
# * **sin(x)**

# %% [markdown]
# ![Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.07.14%20a.%C2%A0m..png](attachment:Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.07.14%20a.%C2%A0m..png)

# %%
def func_sin(x, n):
    approx = 0
    for i in range(n):
        coef = (-1)**i
        num = x ** ( 2*i + 1 )
        denom = math.factorial( 2*i + 1 )
        approx += ( coef ) * ( (num)/(denom) )
        
    return approx

# %%
x = (math.radians(45)); n = 20
print('x = ', x /(math.pi), 'pi ' , ' n = ', n)

out = func_sin(x , n)
print('sin x - Taylor: ', out)

out = math.sin(x)
print('sin x - Library:', out)
# Out:
# x =  0.25 pi   n =  20
# sin x - Taylor:  0.7071067811865475
# sin x - Library: 0.7071067811865475

# %%
# %matplotlib inline

angles = np.arange(-2*np.pi,2*np.pi,0.1)
taylor = np.sin(angles)
function = [func_sin(angle, 5) for angle in angles]

fig, ax = plt.subplots()
ax.plot(angles,taylor)
ax.plot(angles,function)
ax.set_ylim([-5,5])
ax.legend(['sin() function','Taylor Aprox.'])

plt.show()

# %% [markdown]
# * **cos(x)**

# %% [markdown]
# ![Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.22.07%20a.%C2%A0m..png](attachment:Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.22.07%20a.%C2%A0m..png)

# %%
x = (math.radians(60)); n = 20
print('x = ', x /(math.pi), 'pi ' , ' n = ', n)

out = func_cos(x , n)
print('sin x - Taylor: ', out)

out = math.cos(x)
print('sin x - Library:', out)
# Out:
# x =  0.3333333333333333 pi   n =  20
# sin x - Taylor:  0.5000000000000001
# sin x - Library: 0.5000000000000001

# %%
# %matplotlib inline

angles = np.arange(-2*np.pi, 2*np.pi,0.1)
taylor = np.cos(angles)
function = [func_sin(angle, 5) for angle in angles]

fig, ax = plt.subplots()
ax.plot(angles,taylor)
ax.plot(angles,function)
ax.set_ylim([-5,5])
ax.legend(['cos() function','Taylor Aprox.'])

plt.show()

# %% [markdown]
# * **1 / (1 - x)**

# %% [markdown]
# ![Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.23.50%20a.%C2%A0m..png](attachment:Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.23.50%20a.%C2%A0m..png)

# %%
def func_1_x(x, n):
    approx = 0
    for i in range(n):
        
        approx += ( (x ** i) )
        
    return approx

# %%
x = math.pi / 4; n = 20
print('x = ', x, ' n = ', n)

out = func_1_x(x , n)
print('1 / 1- x - Taylor: ', out)

out = 1 / (1 - x)
print('1 / 1 - x - Python:', out)
# Out:
# x =  0.7853981633974483  n =  20
# 1 / 1- x - Taylor:  4.622624794197076
# 1 / 1 - x - Python: 4.659792366325487

# %%
# %matplotlib inline

x_values = np.arange(-1, 1, 0.05)
lib_ex = [ ( 1 / (1-x) ) for x in x_values]
ex = [func_1_x(x, 10) for x in x_values]

fig, ax = plt.subplots()
ax.plot(x_values, lib_ex)
ax.plot(x_values, ex)
ax.set_ylim([-1,2])
ax.legend(['1/(1-x) function','Taylor Aprox.'])

plt.show()

# %% [markdown]
# * **ln (1 + x)**

# %% [markdown]
# ![Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.35.44%20a.%C2%A0m..png](attachment:Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.35.44%20a.%C2%A0m..png)

# %%
def func_ln_x1(x, n):
    approx = 0
    for i in range(n):
        coef = (-1) ** (( i + 1) - 1)
        num = x ** ( i + 1 )
        denom = i + 1
        approx += ( coef ) * ( (num)/(denom) )
        
    return approx

# %%
x = math.pi / 5; n = 20
print('x = ', x, ' n = ', n)

out = func_ln_x1(x, n)
print('ln(x+1) - Taylor: ', out)

out = math.log(1 + x)
print('ln(x+1) - Library:', out)
# Out:
# x =  0.6283185307179586  n =  20
# ln(x+1) - Taylor:  0.48754618571338193
# ln(x+1) - Library: 0.48754790613104304

# %%
x = 0.1
for i in range(1,11):
    e_approx = func_ln_x1(x,i)
    e_exp = math.log(x+1)
    e_error = abs(e_approx - e_exp)
    print(f'{i} terms: Taylor Series approx= {e_approx}, exp calc= {e_exp}, error = {e_error}')
# Out:
# 1 terms: Taylor Series approx= 0.1, exp calc= 0.09531017980432493, error = 0.004689820195675071
# 2 terms: Taylor Series approx= 0.095, exp calc= 0.09531017980432493, error = 0.00031017980432493375
# 3 terms: Taylor Series approx= 0.09533333333333334, exp calc= 0.09531017980432493, error = 2.3153529008404505e-05
# 4 terms: Taylor Series approx= 0.09530833333333334, exp calc= 0.09531017980432493, error = 1.8464709915927413e-06
# 5 terms: Taylor Series approx= 0.09531033333333334, exp calc= 0.09531017980432493, error = 1.5352900840925887e-07
# 6 terms: Taylor Series approx= 0.09531016666666668, exp calc= 0.09531017980432493, error = 1.3137658252948547e-08
# 7 terms: Taylor Series approx= 0.09531018095238097, exp calc= 0.09531017980432493, error = 1.1480560391241568e-09
# 8 terms: Taylor Series approx= 0.09531017970238097, exp calc= 0.09531017980432493, error = 1.0194396715679233e-10
# ...

# %%
# %matplotlib inline

x_values = np.arange(-1, 1, 0.1)
lib_ex = np.log(x_values + 1)
ex = [func_ln_x1(x, 5) for x in x_values]

fig, ax = plt.subplots()
ax.plot(x_values, lib_ex)
ax.plot(x_values, ex)
ax.set_ylim([-1, 1])
ax.legend(['ln( x+1 ) function','Taylor Aprox.'])

plt.show()
# Out:
# <ipython-input-43-b27a35c3d64b>:4: RuntimeWarning: divide by zero encountered in log
#   lib_ex = np.log(x_values + 1)

# %% [markdown]
# * **ln (x)**

# %% [markdown]
# ![Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.41.05%20a.%C2%A0m..png](attachment:Captura%20de%20Pantalla%202020-11-16%20a%20la%28s%29%2011.41.05%20a.%C2%A0m..png)

# %%
def func_ln_x(x, n):
    approx = 0
    for i in range(n):
        coef = (-1) ** (( i + 1) - 1)
        num = (x - 1) ** ( i + 1 )
        denom = i + 1
        approx += ( coef ) * ( (num)/(denom) )
        
    return approx

# %%
x = math.pi / 6; n = 20
print('x = ', x, ' n = ', n)

out = func_ln_x(x, n)
print('1 / 1 - x - Taylor: ', out)

out = math.log(x)
print('1 / 1 - x - Library:', out)
# Out:
# x =  0.5235987755982988  n =  20
# 1 / 1 - x - Taylor:  -0.6470295682708342
# 1 / 1 - x - Library: -0.6470295833786549

# %%
# %matplotlib inline

x_values = np.arange(-1, 1, 0.1)
lib_ex = np.log(x_values)
ex = [func_ln_x(x, 3) for x in x_values]

fig, ax = plt.subplots()
ax.plot(x_values, lib_ex)
ax.plot(x_values, ex)
ax.set_ylim([-1, 1])
ax.legend(['ln(x) function','Taylor Aprox.'])

plt.show()
# Out:
# <ipython-input-42-60aeffb2903e>:4: RuntimeWarning: invalid value encountered in log
#   lib_ex = np.log(x_values)

# %%
print(0x10 + 0b10 + 2)
# Out:
# 20

# %%
import numpy
b = numpy.linspace(-360,0,5)
print(b/90)
# Out:
# [-4. -3. -2. -1.  0.]

# %%
import numpy as np
import matplotlib.pyplot as plt

names = ['group_a', 'group_b', 'group_c']

values = [1, 100, 10]

 

plt.plot(names, values)

plt.suptitle('Categorical Plotting')

plt.show()
