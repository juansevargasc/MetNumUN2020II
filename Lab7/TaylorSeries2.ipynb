# %% [markdown]
# # Laboratory 7
# * **Taylor series expansion**

# %%
from sympy import series, Symbol
from sympy.functions import sin, cos, exp, log
from sympy.plotting import plot
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = 13,10
plt.rcParams['lines.linewidth'] = 2

# %%
# Define symbol
x = Symbol('x')

# %% [markdown]
# **Function Taylor**

# %%
def taylor(function, x0, n):
    """
    Parameter "function" is our function which we want to approximate
    "x0" is the point where to approximate
    "n" is the order of approximation
    """
    return function.series(x,x0,n).removeO()

# %%
def func_1_x_minus_x(x):
    return 1 / (1 - x)

# %% [markdown]
# * **e ^ x**
# * **sin(x)**
# * **cos(x)**
# * **1 / (1 - x)**
# * **ln(1 + x)**
# * **ln(x)**

# %%
print('e(x) =', taylor(exp(x), 0, 4))

print('sin(x) =', taylor(sin(x), 0, 4))

print('cos(x) =', taylor(cos(x), 0, 4))

print('1 / (1-x) =', taylor(func_1_x_minus_x(x), 0, 4))

print('ln(x + 1) =', taylor(log(x + 1), 0, 4))

print('ln(x) =', taylor(log(x), 0, 4))
# Out:
# e(x) = x**3/6 + x**2/2 + x + 1
# sin(x) = -x**3/6 + x
# cos(x) = 1 - x**2/2
# 1 / (1-x) = x**3 + x**2 + x + 1
# ln(x + 1) = x**3/3 - x**2/2 + x
# ln(x) = log(x)

# %%
print('e(1) =', taylor(exp(x), 0, 4).subs(x,1))

print('sin(1) =', taylor(sin(x), 0, 4).subs(x,1))

print('cos(1) =', taylor(cos(x), 0, 4).subs(x,1))

print('1 / (1-x) =', taylor(func_1_x_minus_x(x), 0, 4).subs(x, 1))

print('ln(x + 1) =', taylor(log(x + 1), 0, 4).subs(x, 1))

print('ln(x) =', taylor(log(x), 0, 4).subs(x, 1))
# Out:
# e(1) = 8/3
# sin(1) = 5/6
# cos(1) = 1/2
# 1 / (1-x) = 4
# ln(x + 1) = 5/6
# ln(x) = 0

# %% [markdown]
# * **e(x) plot**

# %%
p = plot(exp(x),taylor(exp(x),0,1),taylor(exp(x),0,2),taylor(exp(x),0,3),
         (x,-2,2),legend=True, show=False)

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Exponent'
p.show()

# %% [markdown]
# * **Sin(x) plot**

# %%
p = plot(sin(x),taylor(sin(x),0,1),taylor(sin(x),0,3),taylor(sin(x),0,5),
         (x,-3.5,3.5),legend=True, show=False)

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Sine'
p.show()

# %% [markdown]
# * **Cos(x) plot**

# %%
p = plot(cos(x),taylor(cos(x),0,2),taylor(cos(x),0,4),taylor(cos(x),0,6),
         (x,-4.5,4.5),legend=True, show=False)

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Cosine'
p.show()

# %% [markdown]
# * **1/ (x - 1) plot**

# %%
p = plot(func_1_x_minus_x(x),taylor(func_1_x_minus_x(x), 0, 1),taylor(func_1_x_minus_x(x),0,5),taylor(func_1_x_minus_x(x),0,10),
         (x,0,0.8),legend=True, show=False)

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion'
p.show()

# %% [markdown]
# * **ln (x + 1) plot**

# %%
p = plot(log(x + 1),taylor(log(x + 1),0,1),taylor(log(x + 1),0,5),taylor(log(x + 1),0,10),
         (x,-1, 1),legend=True, show=False)

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Exponent'
p.show()

# %% [markdown]
# * **ln (x) plot**

# %%
p = plot(log(x),taylor(log(x),0,1),taylor(log(x),0,2),taylor(log(x),0,10),
         (x,-1, 0.5),legend=True, show=False)

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Exponent'
p.show()
